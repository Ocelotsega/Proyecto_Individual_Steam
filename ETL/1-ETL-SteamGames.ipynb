# %% [markdown]
# ---
# # Iniciamos el ETL del primer archivo steam_games

# %% [markdown]
# Importando librerías a utilizar

# %%
import json
import re
import ast
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# ## Cargamos y transformamos la data

# %%
# Extracción del JSON y generación del DataFrame
with open("../DataJSon/output_steam_games.json") as file:
    df = pd.DataFrame([json.loads(line) for line in file.readlines()])

# %%
df.shape
# Out:
# (120445, 13)

# %%
df.describe()
# Out:
#        publisher    genres    app_name       title  \
# count      24083     28852       32133       30085
# unique      8239       883       32094       30054
# top      Ubisoft  [Action]  Soundtrack  Soundtrack
# freq         385      1880           3           3
#
#                                                       url release_date  \
# count                                               32135        30068
# unique                                              32135         3582
# top     http://store.steampowered.com/app/761140/Lost_...   2012-10-16
# freq                                                    1          100
#
#                         tags  \
# count                  31972
# unique                 15395
# top     [Casual, Simulation]
# freq                    1292
#
#                                               reviews_url            specs  \
# count                                               32133            31465
# unique                                              32132             4649
# top     http://steamcommunity.com/app/612880/reviews/?...  [Single-player]
# freq                                                    2             2794
#
#            price early_access      id                developer
# count   30758.00        32135   32133                    28836
# unique    162.00            2   32132                    10992
# top         4.99        False  612880  Ubisoft - San Francisco
# freq     4278.00        30188       2                     1259

# %% [markdown]
# Inspeccionamos la columnas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120445 entries, 0 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  object
#  11  id            32133 non-null  object
#  12  developer     28836 non-null  object
# dtypes: object(13)
# memory usage: 11.9+ MB

# %% [markdown]
# ### Existen columnas que no se utilizan por lo tanto se eliminan con el fin de optimizar el tratamiento de los datos

# %%
games = df.drop(['url', 'reviews_url'], axis=1)
games
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title release_date  \
# 0                            NaN                       NaN          NaN
# 1                            NaN                       NaN          NaN
# 2                            NaN                       NaN          NaN
# 3                            NaN                       NaN          NaN
# 4                            NaN                       NaN          NaN
# ...                          ...                       ...          ...
# 120440            Colony On Mars            Colony On Mars   2018-01-04
# 120441  LOGistICAL: South Africa  LOGistICAL: South Africa   2018-01-04
# 120442             Russian Roads             Russian Roads   2018-01-04
# 120443       EXIT 2 - Directions       EXIT 2 - Directions   2017-09-02
# 120444               Maze Run VR                       NaN          NaN
#
#                                                      tags  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
# 120444  [Early Access, Adventure, Indie, Action, Simul...
#
#                                                     specs price early_access  \
# 0                                                     NaN   NaN          NaN
# 1                                                     NaN   NaN          NaN
# 2                                                     NaN   NaN          NaN
# 3                                                     NaN   NaN          NaN
# 4                                                     NaN   NaN          NaN
# ...                                                   ...   ...          ...
# 120440                [Single-player, Steam Achievements]  1.99        False
# 120441  [Single-player, Steam Achievements, Steam Clou...  4.99        False
# 120442  [Single-player, Steam Achievements, Steam Trad...  1.99        False
# 120443   [Single-player, Steam Achievements, Steam Cloud]  4.99        False
# 120444  [Single-player, Stats, Steam Leaderboards, HTC...  4.99         True
#
#             id                 developer
# 0          NaN                       NaN
# 1          NaN                       NaN
# 2          NaN                       NaN
# 3          NaN                       NaN
# 4          NaN                       NaN
# ...        ...                       ...
# 120440  773640        Nikita "Ghost_RUS"
# 120441  733530                    Sacada
# 120442  610660  Laush Dmitriy Sergeevich
# 120443  658870             xropi,stev3ns
# 120444  681550                       NaN
#
# [120445 rows x 11 columns]

# %% [markdown]
# Iniciamos a tratar los nulos y repetidos

# %% [markdown]
# ## Funciones para ayudarme en la limpieza

# %%
def convert_to_float_or_zero(value):
    """
    Convierte el valor a float; si es un valor str o nulo, devuelve 0.0.
    
    Parameters:
        value (any): El valor a intentar convertir a float.
    
    Returns:
        float: El valor convertido a float o 0.0 si la conversión no es posible.
    """
    if value is None or isinstance(value, str):
        return 0.0
    try:
        return float(value)
    except (ValueError, TypeError):
        return 0.0
def convertir_fecha(df, columna):
    '''
    Convierte los datos de una columna a tipo fecha en formato "año-mes-día".
    Elimina las filas que contienen palabras como 'soon' u otras similares.

    Args:
        df (DataFrame): DataFrame que contiene la columna.
        columna (str): Nombre de la columna a convertir.

    Returns:
        DataFrame: DataFrame con la columna convertida y filas eliminadas.
    '''
    # Crea una copia del DataFrame para evitar modificaciones inesperadas
    df = df.copy()

    # Itera sobre la columna
    for i, fecha in enumerate(df[columna]):
        if pd.notna(fecha):  # Verifica que no sea nulo
            try:
                # Convierte la fecha al formato "año-mes-día"
                fecha_convertida = pd.to_datetime(fecha, errors='raise').strftime('%Y-%m-%d')
                # Asigna la fecha convertida
                df.at[i, columna] = fecha_convertida
            except (ValueError, TypeError):
                # En caso de error o tipo incorrecto, elimina la fila
                df.drop(i, inplace=True)

    # Elimina filas que contienen palabras como 'soon'
    df = df[~df[columna].str.contains(r'\bsoon\b', case=False, na=False)]

    # Reinicia el índice después de eliminar filas
    df.reset_index(drop=True, inplace=True)

    return df
def extraer_anio(fecha): # --- > Esta funcion tiene la tarea de realizar una limpieza de los anios en la columna de release_date, returna solo el anio dejando de lado lo demas
    if '-' in fecha:  # Si el formato es 'YYYY-MM-DD'
        return fecha.split('-')[0]
    else:  # --- >  Si el formato es 'MMM YYYY'
        partes = fecha.split(' ')
        if len(partes) == 2:
            return partes[1]
    return fecha

# %%
games.dropna(thresh=9,inplace=True) #Elimino las filas que cumplen con la condicion de estar completamente sin datos (NaN), de lo contrario si contienen algun valor no se eliminan
games = games.drop(games.loc[games['id'].isna()].index) #Realice una exploracion en la columna id, y tome la desicion de eliminar las filas que no contienen valores, no tienen relevancia en el resto del proceso
games['id'] = games['id'].astype(int) # Realice una conversion en el tipo de dato de la columna id, de Float a Int
games = games.drop_duplicates(subset=['id']) #Comprobe que existen valores repetidos, verifique que todos sus valores sean identicos y luego procedi a realizar su eliminacion.
# Primero comprobe que la columna genres y tags, contienen los mismos valores, complete los faltantes de la columna tags con los valores de la columna genres
filas_vacias = games['tags'].isna() #guardo las filas con valores NaN en tags
games.loc[filas_vacias, 'tags'] = games.loc[filas_vacias, 'genres'] # asigno los valores de la columna genres dentro de la columna tags
# Relleno los valores de la columna publisher, con los valores de la columna developer, solo cuando publisher no tiene ningun valor.
filas_vacias = games['publisher'].isna()
games.loc[filas_vacias, 'publisher'] = games.loc[filas_vacias, 'developer']
# En este caso no elimino ninguna de las columnas, ya que algunos valores que son relevantes tambien son diferentes.
games.dropna(inplace=True) #Elimino todos los NaN
# Utilizo mi funcion extraer_anio guardada y especificada en el directorio funcines, archivo funciones.py
games['release_date'] = games['release_date'].apply(extraer_anio)
# Normalizo los ultimos datos de la columna release_date
games['release_date'] = games['release_date'].replace('SOON™',2019)
games['release_date'] = games['release_date'].replace('soon',2019)
games['release_date'] = games['release_date'].replace('SOON',2019)
# Convierto la columna id de valores str a int
games['id'] = games['id'].astype(int)
# Convierto la columna release_date de valores str a int
games['release_date'] = games['release_date'].astype(int)

# %%
# Elimino las filas que tienen menos de 9 valores no nulos
games.dropna(thresh=9, inplace=True)
# Elimino la columna 'app_name ya que 'title' contiene la misma información y sin faltantes
games.drop(columns='app_name', inplace=True)
# Elimino las filas que no tienen un valor en la columna 'id'
games = games.dropna(subset=['id'])
# Convierto la columna 'id' de float a int
games['id'] = games['id'].astype(int)
# Elimino duplicados basándome en la columna 'id'
games = games.drop_duplicates(subset=['id'])
# Completo los valores faltantes en 'tags' con los valores de 'genres'
games['tags'].fillna(games['genres'], inplace=True)
# Relleno los valores faltantes en 'publisher' con los valores de 'developer' solo si 'publisher' está vacío
games['publisher'].fillna(games['developer'], inplace=True)

# %%
# Normalizo los ultimos datos de la columna release_date
games['release_date'] = games['release_date'].replace('SOON™',2019)
games['release_date'] = games['release_date'].replace('soon',2019)
games['release_date'] = games['release_date'].replace('SOON',2019)

# %%
games.head()
# Out:
#                  publisher                                             genres  \
# 88310            Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311     Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312         Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                 彼岸领域                        [Action, Adventure, Casual]
# 88315  Trickjump Games Ltd                    [Action, Adventure, Simulation]
#
#                          title  release_date  \
# 88310      Lost Summoner Kitty          2018
# 88311                Ironbound          2018
# 88312  Real Pool 3D - Poolians          2017
# 88313                  弹炸人2222          2017
# 88315    Battle Royale Trainer          2018
#
#                                                     tags  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                        [Action, Adventure, Casual]
# 88315  [Action, Adventure, Simulation, FPS, Shooter, ...
#
#                                                    specs         price  \
# 88310                                    [Single-player]          4.99
# 88311  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 88312  [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 88313                                    [Single-player]          0.99
# 88315                [Single-player, Steam Achievements]          3.99
#
#       early_access      id            developer
# 88310        False  761140            Kotoshiro
# 88311        False  643980     Secret Level SRL
# 88312        False  670290         Poolians.com
# 88313        False  767400                 彼岸领域
# 88315        False  772540  Trickjump Games Ltd

# %%
games.dropna(inplace=True)

# %%
games
# Out:
#                   publisher  \
# 88310             Kotoshiro
# 88311      Making Fun, Inc.
# 88312          Poolians.com
# 88313                  彼岸领域
# 88315   Trickjump Games Ltd
# ...                     ...
# 120439      Bidoniera Games
# 120440      Ghost_RUS Games
# 120441               Sacada
# 120442         Laush Studio
# 120443             SIXNAILS
#
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88315                     [Action, Adventure, Simulation]
# ...                                                   ...
# 120439                 [Action, Adventure, Casual, Indie]
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# 120442                        [Indie, Racing, Simulation]
# 120443                                    [Casual, Indie]
#
#                            title  release_date  \
# 88310        Lost Summoner Kitty          2018
# 88311                  Ironbound          2018
# 88312    Real Pool 3D - Poolians          2017
# 88313                    弹炸人2222          2017
# 88315      Battle Royale Trainer          2018
# ...                          ...           ...
# 120439              Kebab it Up!          2018
# 120440            Colony On Mars          2018
# 120441  LOGistICAL: South Africa          2018
# 120442             Russian Roads          2018
# 120443       EXIT 2 - Directions          2017
#
#                                                      tags  \
# 88310       [Strategy, Action, Indie, Casual, Simulation]
# 88311   [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312   [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                         [Action, Adventure, Casual]
# 88315   [Action, Adventure, Simulation, FPS, Shooter, ...
# ...                                                   ...
# 120439        [Action, Indie, Casual, Violent, Adventure]
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
#
#                                                     specs         price  \
# 88310                                     [Single-player]          4.99
# 88311   [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 88312   [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 88313                                     [Single-player]          0.99
# 88315                 [Single-player, Steam Achievements]          3.99
# ...                                                   ...           ...
# 120439   [Single-player, Steam Achievements, Steam Cloud]          1.99
# 120440                [Single-player, Steam Achievements]          1.99
# 120441  [Single-player, Steam Achievements, Steam Clou...          4.99
# 120442  [Single-player, Steam Achievements, Steam Trad...          1.99
# 120443   [Single-player, Steam Achievements, Steam Cloud]          4.99
#
#        early_access      id                 developer
# 88310         False  761140                 Kotoshiro
# 88311         False  643980          Secret Level SRL
# 88312         False  670290              Poolians.com
# 88313         False  767400                      彼岸领域
# 88315         False  772540       Trickjump Games Ltd
# ...             ...     ...                       ...
# 120439        False  745400           Bidoniera Games
# 120440        False  773640        Nikita "Ghost_RUS"
# 120441        False  733530                    Sacada
# 120442        False  610660  Laush Dmitriy Sergeevich
# 120443        False  658870             xropi,stev3ns
#
# [27181 rows x 10 columns]

# %%
games.isna().sum()
# Out:
# publisher       0
# genres          0
# title           0
# release_date    0
# tags            0
# specs           0
# price           0
# early_access    0
# id              0
# developer       0
# dtype: int64

# %% [markdown]
# ## Transformación de los datos

# %%
# conozco que tipos de datos tiene el dataset para saber cual debo modificar
tipos_de_datos=games.dtypes
tipos_de_datos
# Out:
# publisher       object
# genres          object
# title           object
# release_date     int32
# tags            object
# specs           object
# price           object
# early_access    object
# id               int32
# developer       object
# dtype: object

# %%
#Aplicamos una función en la columna price para cambiar el tipo de dato
games['price'] = games['price'].apply(convert_to_float_or_zero)

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27181 entries, 88310 to 120443
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     27181 non-null  object
#  1   genres        27181 non-null  object
#  2   title         27181 non-null  object
#  3   release_date  27181 non-null  int32
#  4   tags          27181 non-null  object
#  5   specs         27181 non-null  object
#  6   price         27181 non-null  float64
#  7   early_access  27181 non-null  object
#  8   id            27181 non-null  int32
#  9   developer     27181 non-null  object
# dtypes: float64(1), int32(2), object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# Usamos un diccionario para examinar las columnas del archivo, después lo convertimos a dataframe. El motivo es que, ya que hay datos anidados, revisamos antes de proseguir con el ETL

# %%
# Genero un diccionario vacío para almacenar los resultados
tipo_data = {"columna": games.columns, "tipos_de_datos": games.applymap(type).nunique()}

# Creo el DataFrame a partir del diccionario
analisis = pd.DataFrame(tipo_data)
analisis
# Out:
#                    columna  tipos_de_datos
# publisher        publisher               1
# genres              genres               1
# title                title               1
# release_date  release_date               1
# tags                  tags               1
# specs                specs               1
# price                price               1
# early_access  early_access               1
# id                      id               1
# developer        developer               1

# %% [markdown]
# Imprimimos una vez más el archivo para comprobar su utilidad

# %%
games.head(15)
# Out:
#                             publisher  \
# 88310                       Kotoshiro
# 88311                Making Fun, Inc.
# 88312                    Poolians.com
# 88313                            彼岸领域
# 88315             Trickjump Games Ltd
# 88316          Poppermost Productions
# 88317          Poppermost Productions
# 88318          Poppermost Productions
# 88322  Stegalosaurus Game Development
# 88323               Copperpick Studio
# 88324                    Ghulam Jewel
# 88325                          Apillo
# 88326          Poppermost Productions
# 88327                          Apillo
# 88328          Poppermost Productions
#
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88315                    [Action, Adventure, Simulation]
# 88316          [Free to Play, Indie, Simulation, Sports]
# 88317          [Free to Play, Indie, Simulation, Sports]
# 88318          [Free to Play, Indie, Simulation, Sports]
# 88322            [Action, Adventure, Casual, Indie, RPG]
# 88323                                    [Casual, Indie]
# 88324                        [Casual, Indie, Simulation]
# 88325   [Adventure, Casual, Indie, Simulation, Strategy]
# 88326          [Free to Play, Indie, Simulation, Sports]
# 88327   [Adventure, Casual, Indie, Simulation, Strategy]
# 88328          [Free to Play, Indie, Simulation, Sports]
#
#                                                    title  release_date  \
# 88310                                Lost Summoner Kitty          2018
# 88311                                          Ironbound          2018
# 88312                            Real Pool 3D - Poolians          2017
# 88313                                            弹炸人2222          2017
# 88315                              Battle Royale Trainer          2018
# 88316                       SNOW - All Access Basic Pass          2018
# 88317                         SNOW - All Access Pro Pass          2018
# 88318                      SNOW - All Access Legend Pass          2018
# 88322  Army of Tentacles: (Not) A Cthulhu Dating Sim:...          2018
# 88323                                        Beach Rules          2018
# 88324                        Planetarium 2 - Zen Odyssey          2018
# 88325                            The first thrust of God          2018
# 88326                                SNOW - Starter Pack          2018
# 88327            The first thrust of God - All Aircrafts          2018
# 88328                               SNOW - Lifetime Pack          2018
#
#                                                     tags  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                        [Action, Adventure, Casual]
# 88315  [Action, Adventure, Simulation, FPS, Shooter, ...
# 88316          [Free to Play, Indie, Simulation, Sports]
# 88317          [Free to Play, Indie, Simulation, Sports]
# 88318          [Free to Play, Indie, Simulation, Sports]
# 88322            [Action, Adventure, RPG, Indie, Casual]
# 88323          [Casual, Indie, Pixel Graphics, Cute, 2D]
# 88324                        [Indie, Casual, Simulation]
# 88325  [Strategy, Adventure, Indie, Casual, Simulatio...
# 88326          [Free to Play, Indie, Simulation, Sports]
# 88327  [Strategy, Adventure, Indie, Casual, Simulatio...
# 88328          [Free to Play, Indie, Simulation, Sports]
#
#                                                    specs  price early_access  \
# 88310                                    [Single-player]   4.99        False
# 88311  [Single-player, Multi-player, Online Multi-Pla...   0.00        False
# 88312  [Single-player, Multi-player, Online Multi-Pla...   0.00        False
# 88313                                    [Single-player]   0.99        False
# 88315                [Single-player, Steam Achievements]   3.99        False
# 88316  [Single-player, Multi-player, Online Multi-Pla...   9.99        False
# 88317  [Single-player, Multi-player, Online Multi-Pla...  18.99        False
# 88318  [Single-player, Multi-player, Online Multi-Pla...  29.99        False
# 88322                [Single-player, Steam Achievements]  10.99        False
# 88323                                    [Single-player]   3.99        False
# 88324                                    [Single-player]   2.99        False
# 88325   [Single-player, Steam Achievements, Steam Cloud]   1.59        False
# 88326  [Single-player, Multi-player, Online Multi-Pla...  14.99        False
# 88327  [Single-player, Downloadable Content, Steam Ac...   1.99        False
# 88328  [Single-player, Multi-player, Online Multi-Pla...  59.99        False
#
#            id                       developer
# 88310  761140                       Kotoshiro
# 88311  643980                Secret Level SRL
# 88312  670290                    Poolians.com
# 88313  767400                            彼岸领域
# 88315  772540             Trickjump Games Ltd
# 88316  774276          Poppermost Productions
# 88317  774277          Poppermost Productions
# 88318  774278          Poppermost Productions
# 88322  770380  Stegalosaurus Game Development
# 88323  768880               Copperpick Studio
# 88324  765320                    Ghulam Jewel
# 88325  773650                          Apillo
# 88326  774271          Poppermost Productions
# 88327  773690                          Apillo
# 88328  774279          Poppermost Productions

# %%
games.tail(15)
# Out:
#                   publisher                                 genres  \
# 120422                   2K                    [Action, Adventure]
# 120423  Topware Interactive                [Action, Casual, Indie]
# 120424                Valve                               [Action]
# 120425   Spiderweb Software                 [Strategy, RPG, Indie]
# 120426     Epic Games, Inc.                               [Action]
# 120427                Valve                               [Action]
# 120432            Fred Ells                                [Indie]
# 120434         Phil Fortier                     [Adventure, Indie]
# 120436   OrtiGames/OrtiSoft                        [Casual, Indie]
# 120437               INGAME                           [Indie, RPG]
# 120439      Bidoniera Games     [Action, Adventure, Casual, Indie]
# 120440      Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441               Sacada              [Casual, Indie, Strategy]
# 120442         Laush Studio            [Indie, Racing, Simulation]
# 120443             SIXNAILS                        [Casual, Indie]
#
#                                                   title  release_date  \
# 120422                                            Mafia          2002
# 120423                               Chicken Shoot Gold          2003
# 120424                                    Day of Defeat          2003
# 120425                                      Geneforge 2          2003
# 120426  Unreal Tournament 2004: Editor's Choice Edition          2004
# 120427                   Counter-Strike: Condition Zero          2004
# 120432                          Agent X: Equation Rider          2018
# 120434               Snail Trek - Chapter 3: Lettuce Be          2018
# 120436                                   Raining blocks          2018
# 120437                                          Bravium          2018
# 120439                                     Kebab it Up!          2018
# 120440                                   Colony On Mars          2018
# 120441                         LOGistICAL: South Africa          2018
# 120442                                    Russian Roads          2018
# 120443                              EXIT 2 - Directions          2017
#
#                                                      tags  \
# 120422  [Action, Adventure, Violent, Story Rich, Class...
# 120423                   [Action, Casual, Indie, Shooter]
# 120424  [FPS, World War II, Multiplayer, Action, Shoot...
# 120425  [RPG, Indie, Strategy, Turn-Based Combat, Isom...
# 120426  [FPS, Arena Shooter, Action, Classic, Multipla...
# 120427  [Action, FPS, Shooter, Multiplayer, Singleplay...
# 120432                                            [Indie]
# 120434  [Adventure, Indie, Retro, Point & Click, Pixel...
# 120436                                    [Indie, Casual]
# 120437                [Indie, RPG, Puzzle, Tower Defense]
# 120439        [Action, Indie, Casual, Violent, Adventure]
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
#
#                                                     specs  price early_access  \
# 120422                                    [Single-player]  14.99        False
# 120423  [Single-player, Multi-player, Steam Trading Ca...   6.99        False
# 120424           [Multi-player, Valve Anti-Cheat enabled]   4.99        False
# 120425                                    [Single-player]  19.99        False
# 120426  [Single-player, Multi-player, Steam Trading Ca...  14.99        False
# 120427  [Single-player, Multi-player, Valve Anti-Cheat...   9.99        False
# 120432                                    [Single-player]   3.99        False
# 120434                [Single-player, Steam Achievements]   0.99        False
# 120436  [Single-player, Shared/Split Screen, Steam Ach...   0.99        False
# 120437  [Single-player, Steam Achievements, Steam Lead...  14.99        False
# 120439   [Single-player, Steam Achievements, Steam Cloud]   1.99        False
# 120440                [Single-player, Steam Achievements]   1.99        False
# 120441  [Single-player, Steam Achievements, Steam Clou...   4.99        False
# 120442  [Single-player, Steam Achievements, Steam Trad...   1.99        False
# 120443   [Single-player, Steam Achievements, Steam Cloud]   4.99        False
#
#             id                                  developer
# 120422   40990                         Illusion Softworks
# 120423  259340                          ToonTRAXX Studios
# 120424      30                                      Valve
# 120425  200980                         Spiderweb Software
# 120426   13230                           Epic Games, Inc.
# 120427      80                                      Valve
# 120432  767010                                  Fred Ells
# 120434  761480                               Phil Fortier
# 120436  767590  Oscar Ortigueira López,OrtiGames/OrtiSoft
# 120437  747320                                     INGAME
# 120439  745400                            Bidoniera Games
# 120440  773640                         Nikita "Ghost_RUS"
# 120441  733530                                     Sacada
# 120442  610660                   Laush Dmitriy Sergeevich
# 120443  658870                              xropi,stev3ns

# %% [markdown]
# ### Transformación de la columna "genres"

# %% [markdown]
# #### Terminada la transformación de los datos numéricos, se trata la columna "genres"

# %%
games["genres"]
# Out:
# 88310         [Action, Casual, Indie, Simulation, Strategy]
# 88311                  [Free to Play, Indie, RPG, Strategy]
# 88312     [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                           [Action, Adventure, Casual]
# 88315                       [Action, Adventure, Simulation]
#                                 ...
# 120439                   [Action, Adventure, Casual, Indie]
# 120440                [Casual, Indie, Simulation, Strategy]
# 120441                            [Casual, Indie, Strategy]
# 120442                          [Indie, Racing, Simulation]
# 120443                                      [Casual, Indie]
# Name: genres, Length: 27181, dtype: object

# %%
#con explode hago que la columna genres tome cada valor que tiene almacenado y lo devuelva en un campo nuevo pero conservando el mismo id
games = games.explode("genres")
games = games.dropna(subset=["genres"])
games
# Out:
#            publisher      genres                title  release_date  \
# 88310      Kotoshiro      Action  Lost Summoner Kitty          2018
# 88310      Kotoshiro      Casual  Lost Summoner Kitty          2018
# 88310      Kotoshiro       Indie  Lost Summoner Kitty          2018
# 88310      Kotoshiro  Simulation  Lost Summoner Kitty          2018
# 88310      Kotoshiro    Strategy  Lost Summoner Kitty          2018
# ...              ...         ...                  ...           ...
# 120442  Laush Studio       Indie        Russian Roads          2018
# 120442  Laush Studio      Racing        Russian Roads          2018
# 120442  Laush Studio  Simulation        Russian Roads          2018
# 120443      SIXNAILS      Casual  EXIT 2 - Directions          2017
# 120443      SIXNAILS       Indie  EXIT 2 - Directions          2017
#
#                                                      tags  \
# 88310       [Strategy, Action, Indie, Casual, Simulation]
# 88310       [Strategy, Action, Indie, Casual, Simulation]
# 88310       [Strategy, Action, Indie, Casual, Simulation]
# 88310       [Strategy, Action, Indie, Casual, Simulation]
# 88310       [Strategy, Action, Indie, Casual, Simulation]
# ...                                                   ...
# 120442                        [Indie, Simulation, Racing]
# 120442                        [Indie, Simulation, Racing]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
#
#                                                     specs  price early_access  \
# 88310                                     [Single-player]   4.99        False
# 88310                                     [Single-player]   4.99        False
# 88310                                     [Single-player]   4.99        False
# 88310                                     [Single-player]   4.99        False
# 88310                                     [Single-player]   4.99        False
# ...                                                   ...    ...          ...
# 120442  [Single-player, Steam Achievements, Steam Trad...   1.99        False
# 120442  [Single-player, Steam Achievements, Steam Trad...   1.99        False
# 120442  [Single-player, Steam Achievements, Steam Trad...   1.99        False
# 120443   [Single-player, Steam Achievements, Steam Cloud]   4.99        False
# 120443   [Single-player, Steam Achievements, Steam Cloud]   4.99        False
#
#             id                 developer
# 88310   761140                 Kotoshiro
# 88310   761140                 Kotoshiro
# 88310   761140                 Kotoshiro
# 88310   761140                 Kotoshiro
# 88310   761140                 Kotoshiro
# ...        ...                       ...
# 120442  610660  Laush Dmitriy Sergeevich
# 120442  610660  Laush Dmitriy Sergeevich
# 120442  610660  Laush Dmitriy Sergeevich
# 120443  658870             xropi,stev3ns
# 120443  658870             xropi,stev3ns
#
# [67484 rows x 10 columns]

# %%
#busco espacios vacios o sin datos 
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67484 entries, 88310 to 120443
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     67484 non-null  object
#  1   genres        67484 non-null  object
#  2   title         67484 non-null  object
#  3   release_date  67484 non-null  int32
#  4   tags          67484 non-null  object
#  5   specs         67484 non-null  object
#  6   price         67484 non-null  float64
#  7   early_access  67484 non-null  object
#  8   id            67484 non-null  int32
#  9   developer     67484 non-null  object
# dtypes: float64(1), int32(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# ## Guardo el dataset como csv

# %%
save = "../DataSets/steam_games.csv"

games.to_csv(save, index=False, encoding="utf-8")

# %% [markdown]
# ## Transformo csv a parquet para una optimización de los archivos

# %%
#Transformo el archivo csv a parquet
#Leo el archivo csv
games= pd.read_csv("../DataSets/steam_games.csv") 

#Indico donde quiero guardar el parquet y con que nombre
output_file= "../DataSets/steam_games.parquet"

#Transformo a traves de una tabla el archivo csv en parquet
table = pa.Table.from_pandas(games)
pq.write_table(table,output_file)
